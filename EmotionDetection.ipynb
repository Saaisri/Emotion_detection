# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

# %%
img = cv2.imread('sad.jpg')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|███████████████████████████████| 4/4 [00:03<00:00,  1.05it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 9.757065215821705e-14,
#   'disgust': 1.0108243981506668e-33,
#   'fear': 9.07645662276826e-22,
#   'happy': 99.99999403953517,
#   'sad': 2.980406040057487e-14,
#   'surprise': 7.129625648493023e-08,
#   'neutral': 6.3506920843783126e-06},
#  'dominant_emotion': 'happy',
#  'region': {'x': 228, 'y': 553, 'w': 641, 'h': 641},
#  'age': 32,
#  'gender': 'Woman',
#  'race': {'asian': 34.17113423347473,
#   'indian': 10.879388451576233,
#   'black': 6.456530839204788,
#   'white': 13.64152878522873,
#   'middle eastern': 5.811126157641411,
#   'latino hispanic': 29.040294885635376},
#  'dominant_race': 'asian'}

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray, 1.1, 4)

for (x, y, w, h) in faces:
    cv2.rectangle (img, (x+10,y+10), (x+w, y+h), (0, 255, 0), 5)
    cv2.putText(img, predictions['dominant_emotion'],(0,50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
